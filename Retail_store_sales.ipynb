# %%
# libraries
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.io as pio

# %%
# load data
df = pd.read_csv(r"C:\retail\Retail_store_sales.csv")

# %% [markdown]
# ## Initial Exploration
# ___

# %%
df.head()
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
#
#    Quantity  Total Spent  Payment Method Location Transaction Date  \
# 0      10.0        185.0  Digital Wallet   Online         4/8/2024
# 1       9.0        261.0  Digital Wallet   Online        7/23/2023
# 2       2.0         43.0     Credit Card   Online        10/5/2022
# 3       9.0        247.5     Credit Card   Online         5/7/2022
# 4       7.0         87.5  Digital Wallet   Online        10/2/2022
#
#   Discount Applied
# 0             True
# 1             True
# 2            False
# 3              NaN
# 4            False

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12575 entries, 0 to 12574
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    12575 non-null  str
#  1   Customer ID       12575 non-null  str
#  2   Category          12575 non-null  str
#  3   Item              11362 non-null  str
#  4   Price Per Unit    11966 non-null  float64
#  5   Quantity          11971 non-null  float64
#  6   Total Spent       11971 non-null  float64
#  7   Payment Method    12575 non-null  str
#  8   Location          12575 non-null  str
#  9   Transaction Date  12575 non-null  str
#  10  Discount Applied  8376 non-null   object
# dtypes: float64(3), object(1), str(7)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#        Price Per Unit      Quantity   Total Spent
# count    11966.000000  11971.000000  11971.000000
# mean        23.365912      5.536380    129.652577
# std         10.743519      2.857883     94.750697
# min          5.000000      1.000000      5.000000
# 25%         14.000000      3.000000     51.000000
# 50%         23.000000      6.000000    108.500000
# 75%         33.500000      8.000000    192.000000
# max         41.000000     10.000000    410.000000

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Customer ID            0
# Category               0
# Item                1213
# Price Per Unit       609
# Quantity             604
# Total Spent          604
# Payment Method         0
# Location               0
# Transaction Date       0
# Discount Applied    4199
# dtype: int64

# %%
df.dtypes
# Out:
# Transaction ID          str
# Customer ID             str
# Category                str
# Item                    str
# Price Per Unit      float64
# Quantity            float64
# Total Spent         float64
# Payment Method          str
# Location                str
# Transaction Date        str
# Discount Applied     object
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## During initial data exploration, I found:
# - ['Item', 'price per unite', 'Quantity', 'Total spend', 'Discount Applied'] Columns have Nulls
# - Incorrect data types for `transaction date`.
# - Zero Dublicated rows
# - Around 40% of the values in `Discount` column is null, I will handle it.

# %% [markdown]
# ## Data cleaning & Preparation
# ---

# %% [markdown]
# ### Handling missing values:

# %%
pd.set_option('future.no_silent_downcasting', True)
# Discount column(True if discount applied)
df['Discount Applied'] = df['Discount Applied'].fillna((df['Price Per Unit'] * df['Quantity']) > df['Total Spent'])
# Out:
# C:\Users\zzvvn\AppData\Local\Temp\ipykernel_19220\1566565748.py:1: Pandas4Warning: 'future.no_silent_downcasting' is deprecated, please refrain from using it.
#   pd.set_option('future.no_silent_downcasting', True)

# %%
df['Item'] = df['Item'].fillna(df['Item'].mode()[0])
df['Price Per Unit'] = df['Price Per Unit'].fillna(df['Price Per Unit'].mean())
df['Quantity'] = df['Quantity'].fillna(df['Quantity'].median())
df['Total Spent'] = df['Total Spent'].fillna(df['Total Spent'].mean())

# %%
#check
df.isnull().sum()
# Out:
# Transaction ID      0
# Customer ID         0
# Category            0
# Item                0
# Price Per Unit      0
# Quantity            0
# Total Spent         0
# Payment Method      0
# Location            0
# Transaction Date    0
# Discount Applied    0
# dtype: int64

# %%
# Renaming colums with lower case letters to work faster.
df.columns = df.columns.str.lower()
# check
df.columns
# Out:
# Index(['transaction id', 'customer id', 'category', 'item', 'price per unit',
#        'quantity', 'total spent', 'payment method', 'location',
#        'transaction date', 'discount applied'],
#       dtype='str')

# %%
# Changing data types
df['transaction date'] = pd.to_datetime(df['transaction date'])

# %%
# check
df.dtypes
# Out:
# transaction id                 str
# customer id                    str
# category                       str
# item                           str
# price per unit             float64
# quantity                   float64
# total spent                float64
# payment method                 str
# location                       str
# transaction date    datetime64[us]
# discount applied            object
# dtype: object

# %% [markdown]
# ### Feature Engineering

# %%
# Day of week
df['day_of_week'] = df['transaction date'].dt.day_name()
# check 
df.sample()
# Out:
#      transaction id customer id                            category  \
# 3931    TXN_9531274     CUST_12  Computers and electric accessories
#
#              item  price per unit  quantity  total spent  payment method  \
# 3931  Item_19_CEA            32.0       5.0        160.0  Digital Wallet
#
#      location transaction date discount applied day_of_week
# 3931   Online       2024-10-21            False      Monday

# %%
# Get season column
season_map = {
    12: "Winter", 1: "Winter", 2: "Winter",
    3: "Spring", 4: "Spring", 5: "Spring",
    6: "Summer", 7: "Summer", 8: "Summer",
    9: "Autumn", 10: "Autumn", 11: "Autumn"
}
df['season'] = df['transaction date'].dt.month.map(season_map)

# %%
# check
df.sample(5)
# Out:
#      transaction id customer id                            category  \
# 3931    TXN_9531274     CUST_12  Computers and electric accessories
# 2079    TXN_2384950     CUST_08  Computers and electric accessories
# 669     TXN_5544428     CUST_18  Computers and electric accessories
# 1809    TXN_5312362     CUST_09                           Furniture
# 1693    TXN_6900244     CUST_15                           Beverages
#
#              item  price per unit  quantity  total spent  payment method  \
# 3931  Item_19_CEA            32.0       5.0   160.000000  Digital Wallet
# 2079   Item_2_BEV            17.0       6.0   129.652577  Digital Wallet
# 669   Item_13_CEA            23.0       8.0   184.000000     Credit Card
# 1809   Item_1_FUR             5.0       4.0    20.000000     Credit Card
# 1693  Item_24_BEV            39.5       6.0   237.000000            Cash
#
#       location transaction date discount applied day_of_week  season
# 3931    Online       2024-10-21            False      Monday  Autumn
# 2079    Online       2023-01-11            False   Wednesday  Winter
# 669     Online       2023-07-25            False     Tuesday  Summer
# 1809  In-store       2024-12-06            False      Friday  Winter
# 1693  In-store       2022-06-25            False    Saturday  Summer

# %%
# Save cleaned data
df.to_csv("cleaned_transactions.csv", index=False)
